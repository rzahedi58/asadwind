# %% [markdown]
# <a href="https://colab.research.google.com/github/rzahedi58/asadwind/blob/main/External_data_Local_Files%2C_Drive%2C_Sheets%2C_and_Cloud_Storage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook provides recipes for loading and saving data from external sources.

# %% [markdown]
# # Local file system

# %% [markdown]
# ## Uploading files from your local file system
#
# `files.upload` returns a dictionary of the files which were uploaded.
# The dictionary is keyed by the file name and values are the data which were uploaded.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# %% [markdown]
# ## Downloading files to your local file system
#
# `files.download` will invoke a browser download of the file to your local computer.

# %%
from google.colab import files

with open('example.txt', 'w') as f:
  f.write('some content')

files.download('example.txt')

# %% [markdown]
# # Google Drive
#
# You can access files in Drive in a number of ways, including:
# - Mounting your Google Drive in the runtime's virtual machine
# - Using a wrapper around the API such as [PyDrive2](https://docs.iterative.ai/PyDrive2/)
# - Using the [native REST API](https://developers.google.com/drive/v3/web/about-sdk)
#
#
#
# Examples of each are below.

# %% [markdown]
# ## Mounting Google Drive locally
#
# The example below shows how to mount your Google Drive on your runtime using an authorization code, and how to write and read files there. Once executed, you will be able to see the new file (`foo.txt`) at [https://drive.google.com/](https://drive.google.com/).
#
# This only supports reading, writing, and moving files; to programmatically modify sharing settings or other metadata, use one of the other options below.
#
# **Note:** When using the 'Mount Drive' button in the file browser, no authentication codes are necessary for notebooks that have only been edited by the current user.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat /content/drive/My\ Drive/foo.txt
# Out:
# Hello Google Drive!

# %%
drive.flush_and_unmount()
print('All changes made in this colab session should now be visible in Drive.')
# Out:
# All changes made in this colab session should now be visible in Drive.

# %% [markdown]
# ## PyDrive2
#
# The examples below demonstrate authentication and file upload/download using PyDrive2. More examples are available in the [PyDrive2 documentation](https://docs.iterative.ai/PyDrive2/).

# %%
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %% [markdown]
# Authenticate and create the PyDrive2 client.

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# Create and upload a text file.

# %%
uploaded = drive.CreateFile({'title': 'Sample upload.txt'})
uploaded.SetContentString('Sample upload file content')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 14vDAdqp7BSCQnoougmgylBexIr2AQx2T

# %% [markdown]
# Load a file by ID and print its contents.

# %%
downloaded = drive.CreateFile({'id': uploaded.get('id')})
print('Downloaded content "{}"'.format(downloaded.GetContentString()))
# Out:
# Downloaded content "Sample upload file content"

# %% [markdown]
# ## Drive REST API
#
# In order to use the Drive API, we must first authenticate and construct an API client.

# %%
from google.colab import auth
auth.authenticate_user()
from googleapiclient.discovery import build
drive_service = build('drive', 'v3')

# %% [markdown]
# With this client, we can use any of the functions in the [Google Drive API reference](https://developers.google.com/drive/v3/reference/). Examples follow.

# %% [markdown]
# ### Creating a new Drive file with data from Python
#
# First, create a local file to upload.

# %%
with open('/tmp/to_upload.txt', 'w') as f:
  f.write('my sample file')

print('/tmp/to_upload.txt contains:')
# !cat /tmp/to_upload.txt
# Out:
# /tmp/to_upload.txt contains:
# my sample file

# %% [markdown]
# Upload it using the [`files.create`](https://developers.google.com/drive/v3/reference/files/create) method. Further details on uploading files are available in the [developer documentation](https://developers.google.com/drive/v3/web/manage-uploads).

# %%
from googleapiclient.http import MediaFileUpload

file_metadata = {
  'name': 'Sample file',
  'mimeType': 'text/plain'
}
media = MediaFileUpload('/tmp/to_upload.txt',
                        mimetype='text/plain',
                        resumable=True)
created = drive_service.files().create(body=file_metadata,
                                       media_body=media,
                                       fields='id').execute()
print('File ID: {}'.format(created.get('id')))
# Out:
# File ID: 1Cw9CqiyU6zbXFD9ViPZu_3yX-sYF4W17

# %% [markdown]
# After executing the cell above, you will see a new file named 'Sample file' at [https://drive.google.com/](https://drive.google.com/).

# %% [markdown]
# ### Downloading data from a Drive file into Python
#
# Download the file we uploaded above.

# %%
file_id = created.get('id')

import io
from googleapiclient.http import MediaIoBaseDownload

request = drive_service.files().get_media(fileId=file_id)
downloaded = io.BytesIO()
downloader = MediaIoBaseDownload(downloaded, request)
done = False
while done is False:
  # _ is a placeholder for a progress object that we ignore.
  # (Our file is small, so we skip reporting progress.)
  _, done = downloader.next_chunk()

downloaded.seek(0)
print('Downloaded file contents are: {}'.format(downloaded.read()))
# Out:
# Downloaded file contents are: b'my sample file'

# %% [markdown]
# In order to download a different file, set `file_id` above to the ID of that file, which will look like "1uBtlaggVyWshwcyP6kEI-y_W3P8D26sz".

# %% [markdown]
# # Google Sheets

# %% [markdown]
# ## Google Sheets Workspace Extension
#
# We have a Workspace Extension, [Sheets to Colab](https://workspace.google.com/u/0/marketplace/app/sheets_to_colab/945625412720), which allows you to directly import data from Google Sheets into Colab from the Sheets UI. Follow the link to the Sheets to Colab Workspace Extension to learn more.

# %% [markdown]
# ## Interacting with Google Sheets using gspread
#
#  You can also use the open-source [`gspread`](https://github.com/burnash/gspread) library to interact with Google Sheets. The code below shows you how to setup and authenticate `gspread`.

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %% [markdown]
# Below is a small set of `gspread` examples. Additional examples are available at the [`gspread` GitHub page](https://github.com/burnash/gspread#more-examples).

# %% [markdown]
# ### Creating a new sheet with data from Python

# %%
sh = gc.create('My cool spreadsheet')

# %% [markdown]
# After executing the cell above, you will see a new spreadsheet named 'My cool spreadsheet' at [https://sheets.google.com](https://sheets.google.com/).
#
# Open our new sheet and add some random data.

# %%
worksheet = gc.open('My cool spreadsheet').sheet1

cell_list = worksheet.range('A1:C2')

import random
for cell in cell_list:
  cell.value = random.randint(1, 10)

worksheet.update_cells(cell_list)
# Out:
# {'spreadsheetId': '1dsQeN0YzXuM387l_CuyEbsYzL2ew9TJFzR-E-RQnwxs',
#  'updatedCells': 6,
#  'updatedColumns': 3,
#  'updatedRange': 'Sheet1!A1:C2',
#  'updatedRows': 2}

# %% [markdown]
# ### Downloading data from a sheet into Python as a Pandas DataFrame
#
# Read back the random data that we inserted above and convert the result into a [Pandas DataFrame](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html).

# %%
worksheet = gc.open('My cool spreadsheet').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print(rows)

import pandas as pd
pd.DataFrame.from_records(rows)
# Out:
# [['6', '3', '4'], ['7', '2', '1']]
#    0  1  2
# 0  6  3  4
# 1  7  2  1

# %% [markdown]
# # InteractiveSheet
#
# You can now embed live Google Sheets in Colab with the `InteractiveSheet` library. This means you can create and edit data in Google Sheets and seamlessly incorporate it into your notebook with Pandas DataFrames all from Colab.

# %%
from google.colab import sheets

# Create a new interactive sheet and add data to it.
sheet = sheets.InteractiveSheet()

# %%
# Get a Pandas DataFrame from the selected worksheet
df = sheet.as_df()

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(10, 4), columns=list('ABCD'))

# Create a new sheet and include the column names as the first row.
sheet = sheets.InteractiveSheet(df=df, title='foo', include_column_headers=True)

# %%
# Push data from Colab to the selected worksheet
df2 = pd.DataFrame(np.random.randn(10, 4), columns=list('ABCD'))
sheet.update(df=df)

# %%
# Display the sheet in the output of the current cell
sheet.display()

# %% [markdown]
# # Google Cloud Storage (GCS)
#
# In order to use Colaboratory with GCS, you'll need to create a [Google Cloud project](https://cloud.google.com/storage/docs/projects) or use a pre-existing one.
#
# Specify your project ID below:

# %%
project_id = 'Your_project_ID_here'

# %% [markdown]
# Files in GCS are contained in [buckets](https://cloud.google.com/storage/docs/buckets).
#
# Buckets must have a globally-unique name, so we generate one here.

# %%
import uuid
bucket_name = 'colab-sample-bucket-' + str(uuid.uuid1())

# %% [markdown]
# In order to access GCS, we must authenticate.

# %%
from google.colab import auth
auth.authenticate_user()

# %% [markdown]
# GCS can be accessed via the `gsutil` command-line utility or via the native Python API.

# %% [markdown]
# ## `gsutil`
#
# First, we configure `gsutil` to use the project we specified above by using `gcloud`.

# %%
# !gcloud config set project {project_id}
# Out:
# Updated property [core/project].

# %% [markdown]
# Create a local file to upload.

# %%
with open('/tmp/to_upload.txt', 'w') as f:
  f.write('my sample file')

print('/tmp/to_upload.txt contains:')
# !cat /tmp/to_upload.txt
# Out:
# /tmp/to_upload.txt contains:
# my sample file

# %% [markdown]
# Make a bucket to which we'll upload the file ([documentation](https://cloud.google.com/storage/docs/gsutil/commands/mb)).

# %%
# !gsutil mb gs://{bucket_name}
# Out:
# Creating gs://colab-sample-bucket-44971372-baaf-11e7-ae30-0242ac110002/...

# %% [markdown]
# Copy the file to our new bucket ([documentation](https://cloud.google.com/storage/docs/gsutil/commands/cp)).

# %%
# !gsutil cp /tmp/to_upload.txt gs://{bucket_name}/
# Out:
# Copying file:///tmp/to_upload.txt [Content-Type=text/plain]...
# / [1 files][   14.0 B/   14.0 B]
# Operation completed over 1 objects/14.0 B.

# %% [markdown]
# Dump the contents of our newly copied file to make sure everything worked ([documentation](https://cloud.google.com/storage/docs/gsutil/commands/cat)).

# %%
# !gsutil cat gs://{bucket_name}/to_upload.txt
# Out:
# my sample file

# %%
# @markdown Once the upload has finished, the data will appear in the Cloud Console storage browser for your project:
print('https://console.cloud.google.com/storage/browser?project=' + project_id)
# Out:
# https://console.cloud.google.com/storage/browser?project=Your_project_ID_here

# %% [markdown]
# Finally, we'll download the file we just uploaded in the example above. It's as simple as reversing the order in the `gsutil cp` command.

# %%
# !gsutil cp gs://{bucket_name}/to_upload.txt /tmp/gsutil_download.txt

# Print the result to make sure the transfer worked.
# !cat /tmp/gsutil_download.txt
# Out:
# Copying gs://colab-sample-bucket483f20dc-baaf-11e7-ae30-0242ac110002/to_upload.txt...
# / [1 files][   14.0 B/   14.0 B]
# Operation completed over 1 objects/14.0 B.
# my sample file

# %% [markdown]
# ## Python API
#
# These snippets based on [a larger example](https://github.com/GoogleCloudPlatform/storage-file-transfer-json-python/blob/master/chunked_transfer.py) that shows additional uses of the API.
#
#  First, we create the service client.

# %%
from googleapiclient.discovery import build
gcs_service = build('storage', 'v1')

# %% [markdown]
# Create a local file to upload.

# %%
with open('/tmp/to_upload.txt', 'w') as f:
  f.write('my sample file')

print('/tmp/to_upload.txt contains:')
# !cat /tmp/to_upload.txt
# Out:
# /tmp/to_upload.txt contains:
# my sample file

# %% [markdown]
# Create a bucket in the project specified above.

# %%
# Use a different globally-unique bucket name from the gsutil example above.
import uuid
bucket_name = 'colab-sample-bucket-' + str(uuid.uuid1())

body = {
  'name': bucket_name,
  # For a full list of locations, see:
  # https://cloud.google.com/storage/docs/bucket-locations
  'location': 'us',
}
gcs_service.buckets().insert(project=project_id, body=body).execute()
print('Done')
# Out:
# Done

# %% [markdown]
# Upload the file to our newly created bucket.

# %%
from googleapiclient.http import MediaFileUpload

media = MediaFileUpload('/tmp/to_upload.txt',
                        mimetype='text/plain',
                        resumable=True)

request = gcs_service.objects().insert(bucket=bucket_name,
                                       name='to_upload.txt',
                                       media_body=media)

response = None
while response is None:
  # _ is a placeholder for a progress object that we ignore.
  # (Our file is small, so we skip reporting progress.)
  _, response = request.next_chunk()

print('Upload complete')
# Out:
# Upload complete

# %%
# @markdown Once the upload has finished, the data will appear in the Cloud Console storage browser for your project:
print('https://console.cloud.google.com/storage/browser?project=' + project_id)
# Out:
# https://console.cloud.google.com/storage/browser?project=Your_project_ID_here

# %% [markdown]
# Download the file we just uploaded.

# %%
from apiclient.http import MediaIoBaseDownload

with open('/tmp/downloaded_from_gcs.txt', 'wb') as f:
  request = gcs_service.objects().get_media(bucket=bucket_name,
                                            object='to_upload.txt')
  media = MediaIoBaseDownload(f, request)

  done = False
  while not done:
    # _ is a placeholder for a progress object that we ignore.
    # (Our file is small, so we skip reporting progress.)
    _, done = media.next_chunk()

print('Download complete')
# Out:
# Download complete

# %% [markdown]
# Inspect the downloaded file.

# %%
# !cat /tmp/downloaded_from_gcs.txt
# Out:
# my sample file

# %%
import netCDF4
import xarray as xr

# %%
dataset = xr.open_dataset('/content/dff90ae61b21d491f9cc53828c55dc82.nc')

# %%
dataset
# Out:
# <xarray.Dataset> Size: 5MB
# Dimensions:         (valid_time: 453, pressure_level: 7, latitude: 3,
#                      longitude: 9)
# Coordinates:
#     number          int64 8B ...
#   * valid_time      (valid_time) datetime64[ns] 4kB 2023-01-01 ... 2023-12-31...
#   * pressure_level  (pressure_level) float64 56B 875.0 850.0 ... 300.0 150.0
#   * latitude        (latitude) float64 24B 35.5 35.25 35.0
#   * longitude       (longitude) float64 72B 50.0 50.25 50.5 ... 51.5 51.75 52.0
#     expver          (valid_time) <U4 7kB ...
# Data variables: (12/16)
#     d               (valid_time, pressure_level, latitude, longitude) float32 342kB ...
#     cc              (valid_time, pressure_level, latitude, longitude) float32 342kB ...
#     z               (valid_time, pressure_level, latitude, longitude) float32 342kB ...
#     o3              (valid_time, pressure_level, latitude, longitude) float32 342kB ...
#     pv              (valid_time, pressure_level, latitude, longitude) float32 342kB ...
#     r               (valid_time, pressure_level, latitude, longitude) float32 342kB ...
#     ...              ...
#     cswc            (valid_time, pressure_level, latitude, longitude) float32 342kB ...
#     t               (valid_time, pressure_level, latitude, longitude) float32 342kB ...
#     u               (valid_time, pressure_level, latitude, longitude) float32 342kB ...
#     v               (valid_time, pressure_level, latitude, longitude) float32 342kB ...
#     w               (valid_time, pressure_level, latitude, longitude) float32 342kB ...
#     vo              (valid_time, pressure_level, latitude, longitude) float32 342kB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-12-15T20:09 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
dataset1 = xr.open_dataset('/content/3574a10b89eca19a5bc5f007b492301a.grib')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-0ca93cb4e630> in <cell line: 1>()
# ----> 1 dataset1 = xr.open_dataset('/content/3574a10b89eca19a5bc5f007b492301a.grib')
#
# /usr/local/lib/python3.10/dist-packages/xarray/backends/api.py in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     650
#     651     if engine is None:
# --> 652         engine = plugins.guess_engine(filename_or_obj)
#     653
#     654     if from_array_kwargs is None:
#
# /usr/local/lib/python3.10/dist-packages/xarray/backends/plugins.py in guess_engine(store_spec)
#     192         )
#     193
# --> 194     raise ValueError(error_msg)
#     195
#     196
#
# ValueError: did not find a match in any of xarray's currently installed IO backends ['netcdf4', 'h5netcdf', 'scipy']. Consider explicitly selecting one of the installed engines via the ``engine`` parameter, or installing additional IO dependencies, see:
# https://docs.xarray.dev/en/stable/getting-started-guide/installing.html
# https://docs.xarray.dev/en/stable/user-guide/io.html

# %%
import xarray as xr

# Load the GRIB file
ds = xr.load_dataset('/content/3574a10b89eca19a5bc5f007b492301a.grib', engine='h5netcdf')

# Check the dataset
print(ds)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     210             try:
# --> 211                 file = self._cache[self._key]
#     212             except KeyError:
#
# /usr/local/lib/python3.10/dist-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      55         with self._lock:
# ---> 56             value = self._cache[key]
#      57             self._cache.move_to_end(key)
#
# KeyError: [<class 'h5netcdf.core.File'>, ('/content/3574a10b89eca19a5bc5f007b492301a.grib',), 'r', (('decode_vlen_strings', True), ('driver', None), ('invalid_netcdf', None)), '25dc2ca2-3d1d-4a49-a07b-ed674f151c7a']
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-21-22994f6fb1c2> in <cell line: 4>()
#       2
#       3 # Load the GRIB file
# ----> 4 ds = xr.load_dataset('/content/3574a10b89eca19a5bc5f007b492301a.grib', engine='h5netcdf')
#       5
#       6 # Check the dataset
#
# /usr/local/lib/python3.10/dist-packages/xarray/backends/api.py in load_dataset(filename_or_obj, **kwargs)
#     306         raise TypeError("cache has no effect in this context")
#     307
# --> 308     with open_dataset(filename_or_obj, **kwargs) as ds:
#     309         return ds.load()
#     310
#
# /usr/local/lib/python3.10/dist-packages/xarray/backends/api.py in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     669
#     670     overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 671     backend_ds = backend.open_dataset(
#     672         filename_or_obj,
#     673         drop_variables=drop_variables,
#
# /usr/local/lib/python3.10/dist-packages/xarray/backends/h5netcdf_.py in open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, format, group, lock, invalid_netcdf, phony_dims, decode_vlen_strings, driver, driver_kwds)
#     429     ) -> Dataset:
#     430         filename_or_obj = _normalize_path(filename_or_obj)
# --> 431         store = H5NetCDFStore.open(
#     432             filename_or_obj,
#     433             format=format,
#
# /usr/local/lib/python3.10/dist-packages/xarray/backends/h5netcdf_.py in open(cls, filename, mode, format, group, lock, autoclose, invalid_netcdf, phony_dims, decode_vlen_strings, driver, driver_kwds)
#     186
#     187         manager = CachingFileManager(h5netcdf.File, filename, mode=mode, kwargs=kwargs)
# --> 188         return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#     189
#     190     def _acquire(self, needs_lock=True):
#
# /usr/local/lib/python3.10/dist-packages/xarray/backends/h5netcdf_.py in __init__(self, manager, group, mode, lock, autoclose)
#     132         # todo: utilizing find_root_and_group seems a bit clunky
#     133         #  making filename available on h5netcdf.Group seems better
# --> 134         self._filename = find_root_and_group(self.ds)[0].filename
#     135         self.is_remote = is_remote_uri(self._filename)
#     136         self.lock = ensure_lock(lock)
#
# /usr/local/lib/python3.10/dist-packages/xarray/backends/h5netcdf_.py in ds(self)
#     197     @property
#     198     def ds(self):
# --> 199         return self._acquire()
#     200
#     201     def open_store_variable(self, name, var):
#
# /usr/local/lib/python3.10/dist-packages/xarray/backends/h5netcdf_.py in _acquire(self, needs_lock)
#     189
#     190     def _acquire(self, needs_lock=True):
# --> 191         with self._manager.acquire_context(needs_lock) as root:
#     192             ds = _nc4_require_group(
#     193                 root, self._group, self._mode, create_group=_h5netcdf_create_group
#
# /usr/lib/python3.10/contextlib.py in __enter__(self)
#     133         del self.args, self.kwds, self.func
#     134         try:
# --> 135             return next(self.gen)
#     136         except StopIteration:
#     137             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.10/dist-packages/xarray/backends/file_manager.py in acquire_context(self, needs_lock)
#     197     def acquire_context(self, needs_lock=True):
#     198         """Context manager for acquiring a file."""
# --> 199         file, cached = self._acquire_with_cache_info(needs_lock)
#     200         try:
#     201             yield file
#
# /usr/local/lib/python3.10/dist-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     215                     kwargs = kwargs.copy()
#     216                     kwargs["mode"] = self._mode
# --> 217                 file = self._opener(*self._args, **kwargs)
#     218                 if self._mode == "w":
#     219                     # ensure file doesn't get overridden when opened again
#
# /usr/local/lib/python3.10/dist-packages/h5netcdf/core.py in __init__(self, path, mode, invalid_netcdf, phony_dims, **kwargs)
#    1520                     self._preexisting_file = os.path.exists(path) and mode != "w"
#    1521                     self._h5py = h5py
# -> 1522                     self._h5file = self._h5py.File(
#    1523                         path, mode, track_order=track_order, **kwargs
#    1524                     )
#
# /usr/local/lib/python3.10/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     559                                  fs_persist=fs_persist, fs_threshold=fs_threshold,
#     560                                  fs_page_size=fs_page_size)
# --> 561                 fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     562
#     563             if isinstance(libver, tuple):
#
# /usr/local/lib/python3.10/dist-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     233         if swmr and swmr_support:
#     234             flags |= h5f.ACC_SWMR_READ
# --> 235         fid = h5f.open(name, flags, fapl=fapl)
#     236     elif mode == 'r+':
#     237         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to synchronously open file (file signature not found)

# %%
pip install pygrib
# Out:
# Collecting pygrib
#   Downloading pygrib-2.1.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from pygrib) (24.2)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.10/dist-packages (from pygrib) (3.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pygrib) (1.26.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj->pygrib) (2024.8.30)
# Downloading pygrib-2.1.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.6/18.6 MB 65.9 MB/s eta 0:00:00
# Installing collected packages: pygrib
# Successfully installed pygrib-2.1.6

# %%
import pygrib

# %%
grbs = pygrib.open('/content/3574a10b89eca19a5bc5f007b492301a.grib')

# %%
grbs

# %%
# Read the messages (data in the file)
for grb in grbs:
    print(grb)  # This will print information about each message

# Close the GRIB2 file
grbs.close()
# Out:
# Streaming output truncated to the last 5000 lines.
# 16263:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201507261200
# 16264:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201507261200
# 16265:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201507270000
# 16266:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201507270000
# 16267:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201507270000
# 16268:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201507270000
# 16269:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201507271200
# 16270:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201507271200
# 16271:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201507271200
# 16272:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201507271200
# 16273:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201507280000
# 16274:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201507280000
# 16275:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201507280000
# 16276:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201507280000
# 16277:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201507281200
# 16278:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201507281200
# 16279:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201507281200
# 16280:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201507281200
# 16281:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201507290000
# 16282:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201507290000
# 16283:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201507290000
# 16284:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201507290000
# 16285:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201507291200
# 16286:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201507291200
# 16287:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201507291200
# 16288:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201507291200
# 16289:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201507300000
# 16290:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201507300000
# 16291:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201507300000
# 16292:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201507300000
# 16293:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201507301200
# 16294:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201507301200
# 16295:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201507301200
# 16296:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201507301200
# 16297:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201507310000
# 16298:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201507310000
# 16299:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201507310000
# 16300:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201507310000
# 16301:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201507311200
# 16302:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201507311200
# 16303:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201507311200
# 16304:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201507311200
# 16305:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508010000
# 16306:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508010000
# 16307:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508010000
# 16308:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508010000
# 16309:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508011200
# 16310:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508011200
# 16311:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508011200
# 16312:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508011200
# 16313:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508020000
# 16314:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508020000
# 16315:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508020000
# 16316:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508020000
# 16317:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508021200
# 16318:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508021200
# 16319:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508021200
# 16320:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508021200
# 16321:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508030000
# 16322:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508030000
# 16323:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508030000
# 16324:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508030000
# 16325:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508031200
# 16326:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508031200
# 16327:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508031200
# 16328:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508031200
# 16329:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508040000
# 16330:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508040000
# 16331:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508040000
# 16332:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508040000
# 16333:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508041200
# 16334:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508041200
# 16335:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508041200
# 16336:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508041200
# 16337:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508050000
# 16338:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508050000
# 16339:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508050000
# 16340:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508050000
# 16341:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508051200
# 16342:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508051200
# 16343:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508051200
# 16344:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508051200
# 16345:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508060000
# 16346:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508060000
# 16347:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508060000
# 16348:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508060000
# 16349:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508061200
# 16350:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508061200
# 16351:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508061200
# 16352:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508061200
# 16353:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508070000
# 16354:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508070000
# 16355:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508070000
# 16356:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508070000
# 16357:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508071200
# 16358:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508071200
# 16359:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508071200
# 16360:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508071200
# 16361:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508080000
# 16362:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508080000
# 16363:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508080000
# 16364:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508080000
# 16365:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508081200
# 16366:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508081200
# 16367:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508081200
# 16368:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508081200
# 16369:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508090000
# 16370:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508090000
# 16371:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508090000
# 16372:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508090000
# 16373:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508091200
# 16374:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 hrs:from 201508091200
# 16375:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201508091200
# 16376:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 hrs:from 201